# %%
from codeapp.utils import get_data_list, calculate_statistics

a = get_data_list()

b = calculate_statistics(a)
# Out:
# [2024-03-08 14:38:47,363] [DEBUG] [urllib3.connectionpool] [connectionpool:1052] - Starting new HTTPS connection (1): onu1.s2.chalmers.se:443
# [2024-03-08 14:38:47,593] [DEBUG] [urllib3.connectionpool] [connectionpool:546] - https://onu1.s2.chalmers.se:443 "GET /datasets/IGN_games.csv HTTP/1.1" 200 1157422
# [2024-03-08 14:38:47,668] [DEBUG] [charset_normalizer] [api:439] - Encoding detection: utf_8 is most likely the one.
# CSV file downloaded successfully as 'IGN_games.csv'
# IGN_games(title='Checkered Flag', score=10.0, score_phrase='Masterpiece', platform='Lynx', genre='Racing', release_year=1999, release_month=7, release_day=6)
# IGN_games(title='Chrono Trigger', score=10.0, score_phrase='Masterpiece', platform='Wii', genre='Action, RPG', release_year=2011, release_month=5, release_day=25)
# IGN_games(title='Dragon Warrior III', score=10.0, score_phrase='Masterpiece', platform='Game Boy Color', genre='RPG', release_year=2001, release_month=7, release_day=20)
# ...
